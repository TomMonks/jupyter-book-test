# %% [markdown]
# # Test page 1

# %%
## a first page for jupyter book

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rng = np.random.default_rng(42)
sample = rng.integers(0, 10, size=1000)

# %%
plt.plot(sample)
